# %% [markdown]
# 1.What is Python, and why is it popular ?
#
# Ans--Python is an interpreted, high levellanguage known for simplicit and readability.
# It is poplular because-
#   1.easy to learn
#   2.having huge library
#   3.open source and community support
#
#
# 2. What is an interpreter in Python?
#
# Ans- An interpreter is a program that executes Python code line by line. Instead of compiling the whole program first, Python's interpreter checks the code line by line.
#
# 3. What are pre-defined keywords in Python?
#
# Ans-- Pre-defined keywords are reserved words in Python that have special meaning and purpose.
# Examples: if, else, for, while, class, def, import, True, False, etc.
#
# 4.Can keywords be used as variable names?
#
# Ans-- No, Keywords cannot be used as variable names because they are reserved word used for specific purposes in Python.
#
# 5. What is mutability in Python?
#
# Ans-- Mutability means the content of an object can be changed after creation.
#
# Mutable objects can be changed
# e.g., lists, dictionaries, sets.
#
# Immutable objects cannot be changed e.g., tuples, strings, integers.
#
#
# 6. Why are lists mutable, but tuples are immutable?
#
# Ans-- Lists: Designed for which we can add the data after creation so that elements can be added, removed, or modified.
#
# Tuples: Designed for fixed data → once created, values cannot be changed, which makes them faster and memory-efficient.
#
# 7. What is the difference between == and is operators in Python?
#
# Ans-- == operator checks values (content equality).
#
# is operator checks identity (whether two objects refer to the same memory location).
#
# 8. What are logical operators in Python?
#
# Ans-- Logical operators are used to combine conditional statements:
#
# and : True if both conditions are true.
#
# or : True if at least one condition is true.
#
# not : Reverses the condition.
#
# 9. What is type casting in Python?
#
# Ans-- Type casting is converting a variable from one data type to another data type.
#
# 10. What is the difference between implicit and explicit type casting?
#
# Ans-- Implicit casting: Done automatically by Python.
# Example: 3 + 4.5 → 7.5.
#
# Explicit casting: Done manually using functions like int(), float(), str().
#
#
# 11. What is the purpose of conditional statements in Python?
#
# Ans-- Conditional statements allow decision-making in code. They execute different blocks of code depending on whether a condition is True or False.
#
# 12. How does the elif statement work?
#
# elif means else if.
# Ans-- If we have more than two condition then we use elif statement.
#
# 13. What is the difference between for and while loops?
#
# Ans-- for loop is used when the number of iterations is known or finite.
#
# while loop is used when we know the condition.
#
# 14. Describe a scenario where a while loop is more suitable than a for loop.
#
# Ans-- it will be better suitable when we know the condtion where the loop will end.

# %% [markdown]
# # Practical Question

# %% [markdown]
# 1. Write a Python program to print "Hello, World!"

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# 2. Write a Python program that displays your name and age

# %%
name = "Deepu"
age = 21
print("Name:", name)
print("Age:", age)
# Out:
# Name: Deepu
# Age: 21

# %% [markdown]
# 3. Write code to print all the pre-defined keywords in Python using the keyword library

# %%
import keyword
print("Python Keywords are:")
print(keyword.kwlist)
# Out:
# Python Keywords are:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# 4. Write a program that checks if a given word is a Python keyword.

# %%
word = input("Enter a word: ")
if keyword.iskeyword(word):
    print(word, "is a Python keyword.")
else:
    print(word, "is NOT a Python keyword.")

# %% [markdown]
# 5. Write a function to demonstrate the behavior of mutable and immutable arguments.

# %%
def modify_list(lst):
    lst.append(10)

def modify_number(num):
    num += 10
    return num

my_list = [1, 2, 3]
modify_list(my_list)
print("After modifying list:", my_list)

x = 5
print("After modifying number:", modify_number(x))
print("Original number:", x)

# %% [markdown]
# 6. Write a program that performs basic arithmetic operations on two user-input numbers.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b if b != 0 else "Undefined (division by zero)")
print("Modulus:", a % b if b != 0 else "Undefined")

# %% [markdown]
# 7. Write a program to demonstrate the use of logical operators.

# %%
x = True
y = False

print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)

# %% [markdown]
# 8. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.

# %%
my_list = [1, 2, 3]
my_list[0] = 10
print("Modified List:", my_list)
my_tuple = (1, 2, 3)
# my_tuple[0] = 10 will give error
print("Tuple cannot be modified:", my_tuple)

# %% [markdown]
# 9. Write a Python program to convert user input from string to integer, float, and boolean types.

# %%
value = input("Enter something: ")

print("In Integer:", int(value))
print("In Float:", float(value))
print("In Boolean:", bool(value))

# %% [markdown]
# 10. Write code to demonstrate type casting with list elements.

# %%
my_list = ["1", "2", "3", "4"]
int_list = [int(x) for x in my_list]
print("Converted to Integers:", int_list)
float_list = [float(x) for x in my_list]
print("Converted to Floats:", float_list)

# %% [markdown]
# 11. Write a program that checks if a number is positive, negative, or zero.

# %%
num = int(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# 12. Write a for loop to print numbers from 1 to 10.

# %%
for i in range(1, 11):
    print(i)

# %% [markdown]
# 13. Write a Python program to find the sum of all even numbers between 1 and 50.

# %%
sum = 0
for i in range(1, 51):
    if i % 2 == 0:
        sum += i
print("Sum of even numbers (1-50):", sum)

# %% [markdown]
# 14. Write a program to reverse a string using a while loop.

# %%
s = input("Enter a string: ")
rev = ""
i = len(s) - 1
while i >= 0:
    rev += s[i]
    i -= 1
print("Reversed String:", rev)

# %% [markdown]
# 15. Write a Python program to calculate the factorial of a number provided by the user using a while loop.

# %%
num = int(input("Enter a number: "))
fact = 1
i = 1
while i <= num:
    fact=fact*i
    i=i+1

print("Factorial of", num, "is", fact)
